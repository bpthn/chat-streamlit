# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/thiradatiamklang/Desktop/iLab/merged_file_final.csv')

# %%
df.head()
# Out:
#                                             Question  Labels
# 0                         Is rehabilitation covered?  list 1
# 1         Are hospital psychiatric services covered?  list 1
# 2                        Is palliative care covered?  list 1
# 3                 Is blood-related services covered?  list 1
# 4  Is bone marrow transfusion or transplant covered?  list 2

# %%
df.tail()
# Out:
#     Question Labels
# 195      NaN    NaN
# 196      NaN    NaN
# 197      NaN    NaN
# 198      NaN    NaN
# 199      NaN    NaN

# %%
cleaned_df = df.dropna()

# %%
print(cleaned_df.isna().sum())
# Out:
# Question    0
# Labels      0
# dtype: int64

# %%
cleaned_df.shape
# Out:
# (195, 2)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# Join all the questions into a single string
text = ' '.join(df['Question'].astype(str))

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud for Questions')
plt.axis('off')
plt.show()
